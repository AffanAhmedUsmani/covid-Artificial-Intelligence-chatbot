# %%
import pandas as pd

df = pd.read_excel("question.xlsx")

# %%
df.iloc[9:25, 2:5]
# Out:
#                                         symptoms_info  \
# 9                              Arthritis and covid19.
# 10                       can coronavirus cause a rash
# 11                     can coronavirus cause diarrhea
# 12                Can you enumerate covid's symptoms?
# 13       Can you explain all the symptoms of Covid19?
# 14     Can you list the symptoms of the corona virus?
# 15  Can you tell me if fever is considered a sympt...
# 16  Can you tell me if the symptoms of COVID-19 ap...
# 17  Can you tell me some of the symptoms of the Vi...
# 18       Can you tell me the symptoms of coronavirus?
# 19                      Can you tell me the symptoms?
# 20    Can you tell what the symptoms of covid-19 are?
# 21                                Chills and covid19.
# 22  Conditions of a person infected with corona virus
# 23                              Cornavirus breathing.
# 24                             Corona and its damage.
#
# ...
